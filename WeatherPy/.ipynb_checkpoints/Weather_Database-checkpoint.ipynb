# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime
from config import weather_api_key as api_key
from citipy import citipy as cp

# %%
lat_list = np.random.uniform(low=-90,high= 90,size= 2000)
long_list = np.random.uniform(low=-180,high= 180,size= 2000)
coordinates = list(zip(lat_list, long_list))

cities =[]
for cd in coordinates:
    city = cp.nearest_city(cd[0], cd[1]).city_name
    
    if(city) not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
record_count = 1
set_count = 1
city_data =[]

# %%
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1      
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0].get("description")
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | west odessa
# Processing Record 3 of Set 1 | geraldton
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | sambava
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | port hardy
# Processing Record 13 of Set 1 | axim
# Processing Record 14 of Set 1 | la palma
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | kuytun
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | quthing
# Processing Record 22 of Set 1 | nouadhibou
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | mount isa
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | fraga
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | crixas
# Processing Record 33 of Set 1 | berlevag
# Processing Record 34 of Set 1 | calvinia
# Processing Record 35 of Set 1 | anloga
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | kuchinarai
# Processing Record 38 of Set 1 | porto novo
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | goundam
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | xai-xai
# Processing Record 43 of Set 1 | cayenne
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | pacifica
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | bud
# Processing Record 48 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 1 | beirut
# Processing Record 50 of Set 1 | anadyr
# Processing Record 1 of Set 2 | rio gallegos
# Processing Record 2 of Set 2 | sibolga
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | biltine
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | durango
# Processing Record 9 of Set 2 | airai
# Processing Record 10 of Set 2 | coquimbo
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | port-gentil
# Processing Record 16 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 2 | sobolevo
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | yaring
# Processing Record 20 of Set 2 | alto longa
# Processing Record 21 of Set 2 | phangnga
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | isangel
# Processing Record 28 of Set 2 | araouane
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | sao lourenco do sul
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | truro
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | tessalit
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | bima
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | terrace bay
# Processing Record 39 of Set 2 | marsh harbour
# Processing Record 40 of Set 2 | ilave
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | edd
# Processing Record 44 of Set 2 | vila velha
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | guerrero negro
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | salalah
# Processing Record 50 of Set 2 | puri
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | peleduy
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | seymchan
# Processing Record 5 of Set 3 | kanbe
# Processing Record 6 of Set 3 | ferme-neuve
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | suzhou
# Processing Record 10 of Set 3 | kamiiso
# Processing Record 11 of Set 3 | madikeri
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | monterey
# Processing Record 14 of Set 3 | sioux lookout
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | lafiagi
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | hambantota
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | kachiry
# Processing Record 22 of Set 3 | powell river
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 3 | moura
# Processing Record 26 of Set 3 | srednekolymsk
# Processing Record 27 of Set 3 | quatre cocos
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | husavik
# Processing Record 30 of Set 3 | puerto baquerizo moreno
# Processing Record 31 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 3 | altay
# Processing Record 35 of Set 3 | kununurra
# Processing Record 36 of Set 3 | disna
# Processing Record 37 of Set 3 | ust-karsk
# Processing Record 38 of Set 3 | los llanos de aridane
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | kaohsiung
# Processing Record 42 of Set 3 | sinnamary
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | havelock
# Processing Record 45 of Set 3 | hamilton
# Processing Record 46 of Set 3 | nemuro
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 49 of Set 3 | guane
# Processing Record 50 of Set 3 | verkhnevilyuysk
# Processing Record 1 of Set 4 | kajaani
# Processing Record 2 of Set 4 | muisne
# Processing Record 3 of Set 4 | noumea
# Processing Record 4 of Set 4 | bermejo
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | soyo
# Processing Record 9 of Set 4 | oktyabrskoye
# Processing Record 10 of Set 4 | amahai
# Processing Record 11 of Set 4 | mnogovershinnyy
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | guilin
# Processing Record 14 of Set 4 | gusau
# Processing Record 15 of Set 4 | vostok
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | ust-koksa
# Processing Record 18 of Set 4 | port elizabeth
# Processing Record 19 of Set 4 | muros
# Processing Record 20 of Set 4 | san vicente
# Processing Record 21 of Set 4 | fort nelson
# Processing Record 22 of Set 4 | farsund
# Processing Record 23 of Set 4 | san policarpo
# Processing Record 24 of Set 4 | clarksdale
# Processing Record 25 of Set 4 | half moon bay
# Processing Record 26 of Set 4 | yerbogachen
# Processing Record 27 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 4 | abu samrah
# Processing Record 29 of Set 4 | ban nahin
# Processing Record 30 of Set 4 | severo-kurilsk
# Processing Record 31 of Set 4 | mwense
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | uk
# City not found. Skipping...
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | tucurui
# Processing Record 37 of Set 4 | tura
# Processing Record 38 of Set 4 | iquitos
# Processing Record 39 of Set 4 | hanzhong
# Processing Record 40 of Set 4 | ixtapa
# Processing Record 41 of Set 4 | hermosillo
# Processing Record 42 of Set 4 | fukue
# Processing Record 43 of Set 4 | bacalar
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | gobabis
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | gloucester
# Processing Record 49 of Set 4 | caibarien
# Processing Record 50 of Set 4 | mashhad
# Processing Record 1 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 5 | camapua
# Processing Record 3 of Set 5 | bahia honda
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | lupiro
# Processing Record 6 of Set 5 | auki
# Processing Record 7 of Set 5 | blois
# Processing Record 8 of Set 5 | truth or consequences
# Processing Record 9 of Set 5 | caravelas
# Processing Record 10 of Set 5 | quelimane
# Processing Record 11 of Set 5 | grand forks
# Processing Record 12 of Set 5 | salinopolis
# Processing Record 13 of Set 5 | bambous virieux
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | athabasca
# Processing Record 17 of Set 5 | ziro
# Processing Record 18 of Set 5 | palmer
# Processing Record 19 of Set 5 | vardo
# Processing Record 20 of Set 5 | netarhat
# Processing Record 21 of Set 5 | peachland
# Processing Record 22 of Set 5 | faanui
# Processing Record 23 of Set 5 | sotouboua
# Processing Record 24 of Set 5 | san pedro de uraba
# Processing Record 25 of Set 5 | alice springs
# Processing Record 26 of Set 5 | nome
# Processing Record 27 of Set 5 | puerto colombia
# Processing Record 28 of Set 5 | coahuayana
# Processing Record 29 of Set 5 | coolum beach
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | berbera
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | poli
# Processing Record 36 of Set 5 | cervena voda
# Processing Record 37 of Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 38 of Set 5 | champerico
# Processing Record 39 of Set 5 | belyy yar
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | torbay
# Processing Record 45 of Set 5 | koshurnikovo
# Processing Record 46 of Set 5 | porto belo
# Processing Record 47 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | hovd
# Processing Record 50 of Set 5 | ust-maya
# Processing Record 1 of Set 6 | werda
# Processing Record 2 of Set 6 | zhucheng
# Processing Record 3 of Set 6 | turukhansk
# Processing Record 4 of Set 6 | dingle
# Processing Record 5 of Set 6 | oranjemund
# Processing Record 6 of Set 6 | broome
# Processing Record 7 of Set 6 | lompoc
# Processing Record 8 of Set 6 | salas
# Processing Record 9 of Set 6 | yar-sale
# Processing Record 10 of Set 6 | riviere-du-loup
# Processing Record 11 of Set 6 | yarim
# Processing Record 12 of Set 6 | comodoro rivadavia
# Processing Record 13 of Set 6 | khuzdar
# Processing Record 14 of Set 6 | zhireken
# Processing Record 15 of Set 6 | kultuk
# Processing Record 16 of Set 6 | jinchang
# Processing Record 17 of Set 6 | dekar
# Processing Record 18 of Set 6 | hirara
# Processing Record 19 of Set 6 | savannah bight
# Processing Record 20 of Set 6 | hobyo
# Processing Record 21 of Set 6 | roald
# Processing Record 22 of Set 6 | goderich
# Processing Record 23 of Set 6 | santa helena de goias
# Processing Record 24 of Set 6 | pontes e lacerda
# Processing Record 25 of Set 6 | sovetskiy
# Processing Record 26 of Set 6 | lancaster
# Processing Record 27 of Set 6 | lavrentiya
# Processing Record 28 of Set 6 | daru
# Processing Record 29 of Set 6 | vanimo
# Processing Record 30 of Set 6 | mezhdurechensk
# Processing Record 31 of Set 6 | kapuskasing
# Processing Record 32 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 6 | mahebourg
# Processing Record 34 of Set 6 | kedgwick
# Processing Record 35 of Set 6 | barranca
# Processing Record 36 of Set 6 | berikulskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | fare
# Processing Record 38 of Set 6 | vredendal
# Processing Record 39 of Set 6 | rocha
# Processing Record 40 of Set 6 | grand gaube
# Processing Record 41 of Set 6 | koutiala
# Processing Record 42 of Set 6 | mayo
# Processing Record 43 of Set 6 | dargaville
# Processing Record 44 of Set 6 | udachnyy
# Processing Record 45 of Set 6 | henties bay
# Processing Record 46 of Set 6 | pouebo
# Processing Record 47 of Set 6 | kasongo-lunda
# Processing Record 48 of Set 6 | kijang
# Processing Record 49 of Set 6 | beloha
# Processing Record 50 of Set 6 | lincoln
# Processing Record 1 of Set 7 | kota bahru
# Processing Record 2 of Set 7 | marmashen
# Processing Record 3 of Set 7 | sechura
# Processing Record 4 of Set 7 | samarai
# Processing Record 5 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 7 | the pas
# Processing Record 7 of Set 7 | methoni
# Processing Record 8 of Set 7 | mitsamiouli
# Processing Record 9 of Set 7 | tarata
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | cabinda
# Processing Record 12 of Set 7 | tilichiki
# Processing Record 13 of Set 7 | energeticheskiy
# Processing Record 14 of Set 7 | jibuti
# Processing Record 15 of Set 7 | masterton
# Processing Record 16 of Set 7 | ostersund
# Processing Record 17 of Set 7 | malim
# Processing Record 18 of Set 7 | praya
# Processing Record 19 of Set 7 | kieta
# Processing Record 20 of Set 7 | kavaratti
# Processing Record 21 of Set 7 | kutum
# Processing Record 22 of Set 7 | college
# Processing Record 23 of Set 7 | springbok
# Processing Record 24 of Set 7 | gorontalo
# Processing Record 25 of Set 7 | victoria
# Processing Record 26 of Set 7 | at-bashi
# Processing Record 27 of Set 7 | morro bay
# Processing Record 28 of Set 7 | ostrovnoy
# Processing Record 29 of Set 7 | jinka
# Processing Record 30 of Set 7 | pran buri
# Processing Record 31 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 32 of Set 7 | swan hill
# Processing Record 33 of Set 7 | narok
# Processing Record 34 of Set 7 | saldanha
# Processing Record 35 of Set 7 | grindavik
# Processing Record 36 of Set 7 | bayonet point
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 7 | alexandria
# Processing Record 40 of Set 7 | acapulco
# Processing Record 41 of Set 7 | kostyantynivka
# Processing Record 42 of Set 7 | tromso
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | kozhva
# Processing Record 45 of Set 7 | buala
# Processing Record 46 of Set 7 | lebu
# Processing Record 47 of Set 7 | marsa matruh
# Processing Record 48 of Set 7 | kisangani
# Processing Record 49 of Set 7 | gourcy
# Processing Record 50 of Set 7 | grafton
# Processing Record 1 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 8 | villa del rosario
# Processing Record 3 of Set 8 | saint-augustin
# Processing Record 4 of Set 8 | san jeronimo
# Processing Record 5 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 6 of Set 8 | hannibal
# Processing Record 7 of Set 8 | serra negra
# Processing Record 8 of Set 8 | buyukcavuslu
# Processing Record 9 of Set 8 | revelstoke
# Processing Record 10 of Set 8 | arman
# Processing Record 11 of Set 8 | westport
# Processing Record 12 of Set 8 | abrau-dyurso
# Processing Record 13 of Set 8 | tawau
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | hokitika
# Processing Record 16 of Set 8 | durban
# Processing Record 17 of Set 8 | dubrovnik
# Processing Record 18 of Set 8 | erenhot
# Processing Record 19 of Set 8 | parambu
# Processing Record 20 of Set 8 | sinegorskiy
# Processing Record 21 of Set 8 | vao
# Processing Record 22 of Set 8 | khatanga
# Processing Record 23 of Set 8 | klaksvik
# Processing Record 24 of Set 8 | jalu
# Processing Record 25 of Set 8 | warrnambool
# Processing Record 26 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 8 | saint anthony
# Processing Record 28 of Set 8 | kalmunai
# Processing Record 29 of Set 8 | kahului
# Processing Record 30 of Set 8 | singapore
# Processing Record 31 of Set 8 | paternion
# Processing Record 32 of Set 8 | pokhara
# Processing Record 33 of Set 8 | sadri
# Processing Record 34 of Set 8 | wanning
# Processing Record 35 of Set 8 | dubbo
# Processing Record 36 of Set 8 | kayes
# Processing Record 37 of Set 8 | thinadhoo
# Processing Record 38 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 8 | carnduff
# Processing Record 40 of Set 8 | kendari
# Processing Record 41 of Set 8 | nipawin
# Processing Record 42 of Set 8 | sisimiut
# Processing Record 43 of Set 8 | rawson
# Processing Record 44 of Set 8 | majene
# Processing Record 45 of Set 8 | tuatapere
# Processing Record 46 of Set 8 | bethel
# Processing Record 47 of Set 8 | ajaccio
# Processing Record 48 of Set 8 | batagay-alyta
# Processing Record 49 of Set 8 | taoudenni
# Processing Record 50 of Set 8 | parabel
# Processing Record 1 of Set 9 | ayer itam
# City not found. Skipping...
# Processing Record 2 of Set 9 | lasa
# Processing Record 3 of Set 9 | paamiut
# Processing Record 4 of Set 9 | kifri
# Processing Record 5 of Set 9 | vad
# Processing Record 6 of Set 9 | harrismith
# Processing Record 7 of Set 9 | les cayes
# Processing Record 8 of Set 9 | camacha
# Processing Record 9 of Set 9 | yumen
# Processing Record 10 of Set 9 | alamogordo
# Processing Record 11 of Set 9 | kirando
# Processing Record 12 of Set 9 | santa fe
# Processing Record 13 of Set 9 | port hedland
# Processing Record 14 of Set 9 | uruzgan
# Processing Record 15 of Set 9 | eraclea
# Processing Record 16 of Set 9 | san andres
# Processing Record 17 of Set 9 | saint-georges
# Processing Record 18 of Set 9 | saint-pierre
# Processing Record 19 of Set 9 | nuuk
# Processing Record 20 of Set 9 | wasilla
# Processing Record 21 of Set 9 | bowen
# Processing Record 22 of Set 9 | oktyabrskiy
# Processing Record 23 of Set 9 | gramesti
# Processing Record 24 of Set 9 | adrar
# Processing Record 25 of Set 9 | seminole
# Processing Record 26 of Set 9 | skjervoy
# Processing Record 27 of Set 9 | somanda
# Processing Record 28 of Set 9 | nieuw amsterdam
# Processing Record 29 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 30 of Set 9 | luau
# Processing Record 31 of Set 9 | kirakira
# Processing Record 32 of Set 9 | sorong
# Processing Record 33 of Set 9 | oyama
# Processing Record 34 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 35 of Set 9 | vanavara
# Processing Record 36 of Set 9 | moerai
# Processing Record 37 of Set 9 | palkonda
# Processing Record 38 of Set 9 | northam
# Processing Record 39 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 9 | brae
# Processing Record 41 of Set 9 | tanout
# Processing Record 42 of Set 9 | kaitangata
# Processing Record 43 of Set 9 | nanortalik
# Processing Record 44 of Set 9 | verkhniy fiagdon
# Processing Record 45 of Set 9 | aykhal
# Processing Record 46 of Set 9 | luganville
# Processing Record 47 of Set 9 | lubao
# Processing Record 48 of Set 9 | pyapon
# Processing Record 49 of Set 9 | tigzirt
# Processing Record 50 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 10 | katsuura
# Processing Record 2 of Set 10 | trelleborg
# Processing Record 3 of Set 10 | itamarandiba
# Processing Record 4 of Set 10 | jatai
# Processing Record 5 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 10 | bimbo
# Processing Record 7 of Set 10 | magoula
# Processing Record 8 of Set 10 | mehamn
# Processing Record 9 of Set 10 | santa
# Processing Record 10 of Set 10 | ponta delgada
# Processing Record 11 of Set 10 | waingapu
# Processing Record 12 of Set 10 | tonj
# Processing Record 13 of Set 10 | inta
# Processing Record 14 of Set 10 | tezu
# Processing Record 15 of Set 10 | payson
# Processing Record 16 of Set 10 | pokaran
# Processing Record 17 of Set 10 | tiznit
# Processing Record 18 of Set 10 | latung
# Processing Record 19 of Set 10 | buchanan
# Processing Record 20 of Set 10 | maragogi
# Processing Record 21 of Set 10 | verkhoyansk
# Processing Record 22 of Set 10 | moi
# Processing Record 23 of Set 10 | bosaso
# Processing Record 24 of Set 10 | svetlyy
# Processing Record 25 of Set 10 | haukipudas
# Processing Record 26 of Set 10 | mildura
# Processing Record 27 of Set 10 | shubarshi
# Processing Record 28 of Set 10 | pangody
# Processing Record 29 of Set 10 | kingisepp
# Processing Record 30 of Set 10 | privokzalnyy
# City not found. Skipping...
# Processing Record 31 of Set 10 | egvekinot
# Processing Record 32 of Set 10 | mae hong son
# Processing Record 33 of Set 10 | tukrah
# Processing Record 34 of Set 10 | alofi
# Processing Record 35 of Set 10 | tadine
# Processing Record 36 of Set 10 | matara
# Processing Record 37 of Set 10 | malanje
# Processing Record 38 of Set 10 | naron
# Processing Record 39 of Set 10 | port lincoln
# Processing Record 40 of Set 10 | santa isabel do rio negro
# Processing Record 41 of Set 10 | misratah
# Processing Record 42 of Set 10 | ahipara
# Processing Record 43 of Set 10 | lapeer
# Processing Record 44 of Set 10 | tangi
# Processing Record 45 of Set 10 | saint-joseph
# Processing Record 46 of Set 10 | puerto del rosario
# Processing Record 47 of Set 10 | yenagoa
# Processing Record 48 of Set 10 | carballo
# Processing Record 49 of Set 10 | neijiang
# Processing Record 50 of Set 10 | nabire
# Processing Record 1 of Set 11 | samfya
# Processing Record 2 of Set 11 | payo
# Processing Record 3 of Set 11 | kemalpasa
# Processing Record 4 of Set 11 | jutai
# Processing Record 5 of Set 11 | emba
# Processing Record 6 of Set 11 | kudahuvadhoo
# Processing Record 7 of Set 11 | san francisco
# Processing Record 8 of Set 11 | atherton
# Processing Record 9 of Set 11 | altamira
# Processing Record 10 of Set 11 | antsohihy
# Processing Record 11 of Set 11 | kalaleh
# Processing Record 12 of Set 11 | praia
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | san cosme y damian
# Processing Record 15 of Set 11 | asau
# Processing Record 16 of Set 11 | hamada
# Processing Record 17 of Set 11 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 18 of Set 11 | brainerd
# Processing Record 19 of Set 11 | mpanda
# Processing Record 20 of Set 11 | chaman
# Processing Record 21 of Set 11 | marshall
# Processing Record 22 of Set 11 | sept-iles
# Processing Record 23 of Set 11 | morehead
# Processing Record 24 of Set 11 | jacareacanga
# Processing Record 25 of Set 11 | lima
# Processing Record 26 of Set 11 | antigonish
# Processing Record 27 of Set 11 | hadejia
# Processing Record 28 of Set 11 | izhma
# Processing Record 29 of Set 11 | nantucket
# Processing Record 30 of Set 11 | gidole
# Processing Record 31 of Set 11 | verkhniye tatyshly
# Processing Record 32 of Set 11 | sorland
# Processing Record 33 of Set 11 | impfondo
# Processing Record 34 of Set 11 | the valley
# Processing Record 35 of Set 11 | chumikan
# Processing Record 36 of Set 11 | toora-khem
# Processing Record 37 of Set 11 | puerto leguizamo
# Processing Record 38 of Set 11 | chara
# Processing Record 39 of Set 11 | obera
# Processing Record 40 of Set 11 | sao joao da barra
# Processing Record 41 of Set 11 | aklavik
# Processing Record 42 of Set 11 | collie
# Processing Record 43 of Set 11 | havoysund
# Processing Record 44 of Set 11 | olafsvik
# Processing Record 45 of Set 11 | whitehorse
# Processing Record 46 of Set 11 | lata
# Processing Record 47 of Set 11 | zaragoza
# Processing Record 48 of Set 11 | chapleau
# Processing Record 49 of Set 11 | ritchie
# Processing Record 50 of Set 11 | souillac
# Processing Record 1 of Set 12 | aldan
# Processing Record 2 of Set 12 | kursk
# Processing Record 3 of Set 12 | harper
# Processing Record 4 of Set 12 | atsiki
# City not found. Skipping...
# Processing Record 5 of Set 12 | boende
# Processing Record 6 of Set 12 | jablah
# Processing Record 7 of Set 12 | belawan
# Processing Record 8 of Set 12 | santa marta
# Processing Record 9 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 12 | biryukove
# Processing Record 11 of Set 12 | byron bay
# Processing Record 12 of Set 12 | voyvozh
# Processing Record 13 of Set 12 | washington
# Processing Record 14 of Set 12 | plouzane
# Processing Record 15 of Set 12 | clearlake
# Processing Record 16 of Set 12 | north port
# Processing Record 17 of Set 12 | dunedin
# Processing Record 18 of Set 12 | saint-francois
# Processing Record 19 of Set 12 | nouna
# Processing Record 20 of Set 12 | shirokiy
# Processing Record 21 of Set 12 | jardim
# Processing Record 22 of Set 12 | gimli
# Processing Record 23 of Set 12 | new agutaya
# Processing Record 24 of Set 12 | broken hill
# Processing Record 25 of Set 12 | narrabri
# Processing Record 26 of Set 12 | nyrob
# Processing Record 27 of Set 12 | salym
# Processing Record 28 of Set 12 | avera
# Processing Record 29 of Set 12 | beaverlodge
# Processing Record 30 of Set 12 | nadvoitsy
# Processing Record 31 of Set 12 | fairbanks
# Processing Record 32 of Set 12 | owando
# Processing Record 33 of Set 12 | hof
# Processing Record 34 of Set 12 | vila
# Processing Record 35 of Set 12 | caconda
# Processing Record 36 of Set 12 | macherla
# Processing Record 37 of Set 12 | lundazi
# Processing Record 38 of Set 12 | bilibino
# Processing Record 39 of Set 12 | mana
# Processing Record 40 of Set 12 | boa vista
# Processing Record 41 of Set 12 | emerald
# Processing Record 42 of Set 12 | fort abbas
# Processing Record 43 of Set 12 | itaituba
# Processing Record 44 of Set 12 | macara
# Processing Record 45 of Set 12 | castilho
# Processing Record 46 of Set 12 | roblin
# Processing Record 47 of Set 12 | villaviciosa
# Processing Record 48 of Set 12 | naqadeh
# Processing Record 49 of Set 12 | bodden town
# Processing Record 50 of Set 12 | vestmannaeyjar
# Processing Record 1 of Set 13 | presidencia roque saenz pena
# Processing Record 2 of Set 13 | tripoli
# Processing Record 3 of Set 13 | kyabram
# Processing Record 4 of Set 13 | tuxtepec
# Processing Record 5 of Set 13 | kokkola
# Processing Record 6 of Set 13 | levelek
# Processing Record 7 of Set 13 | mossendjo
# Processing Record 8 of Set 13 | zhuanghe
# Processing Record 9 of Set 13 | sembe
# Processing Record 10 of Set 13 | banda aceh
# Processing Record 11 of Set 13 | ortona
# Processing Record 12 of Set 13 | nyurba
# Processing Record 13 of Set 13 | manggar
# Processing Record 14 of Set 13 | rawlins
# Processing Record 15 of Set 13 | bathsheba
# Processing Record 16 of Set 13 | port blair
# Processing Record 17 of Set 13 | uni
# Processing Record 18 of Set 13 | medicine hat
# Processing Record 19 of Set 13 | jaisalmer
# Processing Record 20 of Set 13 | saint-gabriel
# Processing Record 21 of Set 13 | skender vakuf
# Processing Record 22 of Set 13 | channel-port aux basques
# Processing Record 23 of Set 13 | ayan
# Processing Record 24 of Set 13 | haines junction
# Processing Record 25 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 13 | bucerias
# Processing Record 28 of Set 13 | roma
# Processing Record 29 of Set 13 | aswan
# Processing Record 30 of Set 13 | guangyuan
# Processing Record 31 of Set 13 | bone
# Processing Record 32 of Set 13 | halifax
# Processing Record 33 of Set 13 | minsk
# Processing Record 34 of Set 13 | pangoa
# Processing Record 35 of Set 13 | plettenberg bay
# Processing Record 36 of Set 13 | constitucion
# Processing Record 37 of Set 13 | chapais
# Processing Record 38 of Set 13 | minab
# Processing Record 39 of Set 13 | moose factory
# Processing Record 40 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 13 | jubayl
# City not found. Skipping...
# Processing Record 42 of Set 13 | rochegda
# Processing Record 43 of Set 13 | banff
# Processing Record 44 of Set 13 | boyolangu
# Processing Record 45 of Set 13 | ocos
# Processing Record 46 of Set 13 | ugoofaaru
# Processing Record 47 of Set 13 | bougouni
# Processing Record 48 of Set 13 | poya
# Processing Record 49 of Set 13 | preobrazheniye
# Processing Record 50 of Set 13 | menongue
# Processing Record 1 of Set 14 | jining
# Processing Record 2 of Set 14 | longyearbyen
# Processing Record 3 of Set 14 | stephenville
# Processing Record 4 of Set 14 | maxixe
# Processing Record 5 of Set 14 | vaitape
# Processing Record 6 of Set 14 | shimoda
# Processing Record 7 of Set 14 | alta gracia
# Processing Record 8 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 14 | greenville
# Processing Record 10 of Set 14 | smithers
# Processing Record 11 of Set 14 | belmonte
# Processing Record 12 of Set 14 | ormara
# Processing Record 13 of Set 14 | tucumcari
# Processing Record 14 of Set 14 | shitanjing
# Processing Record 15 of Set 14 | zhanaozen
# Processing Record 16 of Set 14 | toamasina
# Processing Record 17 of Set 14 | brive-la-gaillarde
# Processing Record 18 of Set 14 | richards bay
# Processing Record 19 of Set 14 | xining
# Processing Record 20 of Set 14 | ilhabela
# Processing Record 21 of Set 14 | alencon
# Processing Record 22 of Set 14 | maningrida
# Processing Record 23 of Set 14 | prince rupert
# Processing Record 24 of Set 14 | safaga
# Processing Record 25 of Set 14 | cairns
# Processing Record 26 of Set 14 | faya
# Processing Record 27 of Set 14 | puerto carreno
# Processing Record 28 of Set 14 | peniche
# Processing Record 29 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 14 | tianpeng
# Processing Record 31 of Set 14 | termiz
# Processing Record 32 of Set 14 | outjo
# Processing Record 33 of Set 14 | nhamunda
# Processing Record 34 of Set 14 | stolin
# Processing Record 35 of Set 14 | catia la mar
# Processing Record 36 of Set 14 | mao
# Processing Record 37 of Set 14 | micheweni
# Processing Record 38 of Set 14 | christchurch
# Processing Record 39 of Set 14 | iquique
# Processing Record 40 of Set 14 | luanda
# Processing Record 41 of Set 14 | finca blanco
# Processing Record 42 of Set 14 | mahanje
# Processing Record 43 of Set 14 | muskogee
# Processing Record 44 of Set 14 | prainha
# Processing Record 45 of Set 14 | malvern
# Processing Record 46 of Set 14 | san carlos de bariloche
# Processing Record 47 of Set 14 | waddan
# Processing Record 48 of Set 14 | abonnema
# Processing Record 49 of Set 14 | xinqing
# Processing Record 50 of Set 14 | dodge city
# Processing Record 1 of Set 15 | san carlos del zulia
# Processing Record 2 of Set 15 | sarangani
# Processing Record 3 of Set 15 | lyuban
# Processing Record 4 of Set 15 | sibu
# Processing Record 5 of Set 15 | parola
# Processing Record 6 of Set 15 | kungsbacka
# Processing Record 7 of Set 15 | verkhnyaya inta
# Processing Record 8 of Set 15 | zyryanka
# Processing Record 9 of Set 15 | gainesville
# Processing Record 10 of Set 15 | bemidji
# Processing Record 11 of Set 15 | itatiba
# Processing Record 12 of Set 15 | kabo
# Processing Record 13 of Set 15 | bandar-e lengeh
# Processing Record 14 of Set 15 | alappuzha
# Processing Record 15 of Set 15 | tazovskiy
# Processing Record 16 of Set 15 | kasama
# Processing Record 17 of Set 15 | sadon
# Processing Record 18 of Set 15 | nara
# Processing Record 19 of Set 15 | novyy urgal
# Processing Record 20 of Set 15 | kampli
# Processing Record 21 of Set 15 | kuusamo
# Processing Record 22 of Set 15 | surt
# Processing Record 23 of Set 15 | troitsko-pechorsk
# Processing Record 24 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 15 | kailua
# Processing Record 26 of Set 15 | glenwood springs
# Processing Record 27 of Set 15 | margate
# Processing Record 28 of Set 15 | bichura
# Processing Record 29 of Set 15 | linxia
# Processing Record 30 of Set 15 | creel
# Processing Record 31 of Set 15 | pingyin
# Processing Record 32 of Set 15 | nola
# Processing Record 33 of Set 15 | springdale
# Processing Record 34 of Set 15 | davila
# Processing Record 35 of Set 15 | katima mulilo
# Processing Record 36 of Set 15 | san patricio
# Processing Record 37 of Set 15 | ilebo
# Processing Record 38 of Set 15 | banjarmasin
# Processing Record 39 of Set 15 | nova dubnica
# Processing Record 40 of Set 15 | nianzishan
# Processing Record 41 of Set 15 | valea dragului
# Processing Record 42 of Set 15 | shache
# Processing Record 43 of Set 15 | wamba
# Processing Record 44 of Set 15 | dinguiraye
# Processing Record 45 of Set 15 | cradock
# Processing Record 46 of Set 15 | topolobampo
# Processing Record 47 of Set 15 | pahrump
# Processing Record 48 of Set 15 | zhezkazgan
# Processing Record 49 of Set 15 | kysyl-syr
# Processing Record 50 of Set 15 | anupgarh
# Processing Record 1 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 16 | jiangdu
# Processing Record 3 of Set 16 | portland
# Processing Record 4 of Set 16 | zachagansk
# City not found. Skipping...
# Processing Record 5 of Set 16 | nalut
# Processing Record 6 of Set 16 | wanaka
# Processing Record 7 of Set 16 | marzuq
# Processing Record 8 of Set 16 | ikole
# City not found. Skipping...
# Processing Record 9 of Set 16 | ambon
# Processing Record 10 of Set 16 | zhangye
# Processing Record 11 of Set 16 | luebo
# Processing Record 12 of Set 16 | veselynove
# Processing Record 13 of Set 16 | bonoua
# Processing Record 14 of Set 16 | baykit
# Processing Record 15 of Set 16 | rzhev
# Processing Record 16 of Set 16 | malartic
# Processing Record 17 of Set 16 | tunduru
# City not found. Skipping...
# Processing Record 18 of Set 16 | viedma
# Processing Record 19 of Set 16 | atar
# Processing Record 20 of Set 16 | tokat
# Processing Record 21 of Set 16 | mentok
# City not found. Skipping...
# Processing Record 22 of Set 16 | ayr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
